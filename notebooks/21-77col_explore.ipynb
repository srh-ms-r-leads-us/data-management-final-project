# %%
import pandas as pd
import numpy as np
from pathlib import Path
df = pd.read_csv("/Users/weijize/Desktop/fifa21_raw_data_v2.csv")
# Out:
# /var/folders/24/329psd4j48qbyynn8cb1j7pc0000gn/T/ipykernel_51724/2704520214.py:4: DtypeWarning: Columns (76) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/weijize/Desktop/fifa21_raw_data_v2.csv")

# %%
# ================================
# SELECT REMAINING COLUMNS
# (21 -> 77)
# ================================

df = df[df.columns[20:77]]

# show dataframe
df
# Out:
#         Wage Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# 0      €560K        €138.4M        429        85         95                70
# 1      €220K         €75.9M        437        84         95                90
# 2      €125K        €159.4M         95        13         11                15
# 3      €370K          €161M        407        94         82                55
# 4      €270K        €166.5M        408        85         87                62
# ...      ...            ...        ...       ...        ...               ...
# 18974    €1K           €70K        145        23         26                43
# 18975   €500          €165K        211        38         42                40
# 18976   €500          €131K        200        30         34                43
# 18977    €2K           €88K        215        45         52                34
# 18978    €1K           €79K        163        40         18                40
#
# ...

# %%
df.columns.tolist()
# Out:
# ['Wage',
#  'Release Clause',
#  'Attacking',
#  'Crossing',
#  'Finishing',
#  'Heading Accuracy',
#  'Short Passing',
#  'Volleys',
#  'Skill',
#  'Dribbling',
#  'Curve',
#  'FK Accuracy',
#  'Long Passing',
#  'Ball Control',
#  'Movement',
#  'Acceleration',
#  'Sprint Speed',
#  'Agility',
#  'Reactions',
#  'Balance',
#  'Power',
#  'Shot Power',
#  'Jumping',
#  'Stamina',
#  'Strength',
#  'Long Shots',
#  'Mentality',
#  'Aggression',
#  'Interceptions',
#  'Positioning',
#  'Vision',
#  'Penalties',
#  'Composure',
#  'Defending',
#  'Marking',
#  'Standing Tackle',
#  'Sliding Tackle',
#  'Goalkeeping',
#  'GK Diving',
#  'GK Handling',
#  'GK Kicking',
#  'GK Positioning',
#  'GK Reflexes',
#  'Total Stats',
#  'Base Stats',
#  'W/F',
#  'SM',
#  'A/W',
#  'D/W',
#  'IR',
#  'PAC',
#  'SHO',
#  'PAS',
#  'DRI',
#  'DEF',
#  'PHY',
#  'Hits']

# %%
# CHECK DUPLICATE IDS

print(len(df))
print(len(df.drop_duplicates()))
# Out:
# 18979
# 18979

# %%
# CHECK MISSING VALUES

df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Hits    2595
# dtype: int64

# %%
df['Wage'].unique().tolist()
# Out:
# ['€560K',
#  '€220K',
#  '€125K',
#  '€370K',
#  '€270K',
#  '€240K',
#  '€250K',
#  '€160K',
#  '€260K',
#  '€210K',
#  '€310K',
#  '€130K',
#  '€350K',
#  '€300K',
#  '€190K',
#  '€145K',
#  '€195K',
#  '€100K',
#  '€140K',
#  '€290K',
#  '€82K',
#  '€110K',
#  '€230K',
#  '€155K',
#  '€200K',
#  '€165K',
#  '€95K',
#  '€170K',
#  '€105K',
#  '€115K',
#  '€150K',
#  '€135K',
#  '€55K',
#  '€58K',
#  '€81K',
#  '€34K',
#  '€120K',
#  '€59K',
#  '€90K',
#  '€65K',
#  '€56K',
#  '€71K',
#  '€18K',
#  '€75K',
#  '€47K',
#  '€20K',
#  '€84K',
#  '€86K',
#  '€74K',
#  '€78K',
#  '€27K',
#  '€68K',
#  '€85K',
#  '€25K',
#  '€46K',
#  '€83K',
#  '€54K',
#  '€79K',
#  '€175K',
#  '€43K',
#  '€49K',
#  '€45K',
#  '€38K',
#  '€41K',
#  '€39K',
#  '€23K',
#  '€51K',
#  '€50K',
#  '€87K',
#  '€30K',
#  '€14K',
#  '€69K',
#  '€31K',
#  '€64K',
#  '€53K',
#  '€35K',
#  '€21K',
#  '€28K',
#  '€17K',
#  '€33K',
#  '€70K',
#  '€32K',
#  '€89K',
#  '€26K',
#  '€40K',
#  '€76K',
#  '€72K',
#  '€48K',
# ...

# %%
df['Release Clause'].unique().tolist()
# Out:
# ['€138.4M',
#  '€75.9M',
#  '€159.4M',
#  '€161M',
#  '€166.5M',
#  '€132M',
#  '€144.3M',
#  '€120.3M',
#  '€203.1M',
#  '€147.7M',
#  '€145.3M',
#  '€122M',
#  '€119M',
#  '€47.9M',
#  '€108.7M',
#  '€50.2M',
#  '€98.1M',
#  '€139.6M',
#  '€96.9M',
#  '€112.1M',
#  '€122.5M',
#  '€103M',
#  '€140.2M',
#  '€27.2M',
#  '€85M',
#  '€118.9M',
#  '€112.8M',
#  '€103.5M',
#  '€132.1M',
#  '€115.5M',
#  '€102M',
#  '€107.8M',
#  '€124.4M',
#  '€104.9M',
#  '€99.8M',
#  '€96.2M',
#  '€50M',
#  '€25.6M',
#  '€77.9M',
#  '€85.5M',
#  '€56.1M',
#  '€72.2M',
#  '€64.6M',
#  '€51.3M',
#  '€82.5M',
#  '€69.3M',
#  '€59.9M',
#  '€98.8M',
#  '€96.3M',
#  '€53.2M',
#  '€43.1M',
#  '€48.5M',
#  '€47.3M',
#  '€58.7M',
#  '€65.6M',
#  '€67.5M',
#  '€84.7M',
#  '€87M',
#  '€95.8M',
#  '€119.7M',
#  '€91.6M',
#  '€79M',
#  '€111.3M',
#  '€78.9M',
#  '€81.9M',
#  '€88.8M',
#  '€86.9M',
#  '€94.6M',
#  '€69.4M',
#  '€78M',
#  '€97.8M',
#  '€86.6M',
#  '€107.3M',
#  '€63.8M',
#  '€54.2M',
#  '€21.9M',
# ...

# %%
df['Attacking'].unique().tolist()
# Out:
# [429,
#  437,
#  95,
#  407,
#  408,
#  423,
#  392,
#  114,
#  118,
#  316,
#  410,
#  349,
#  86,
#  119,
#  426,
#  374,
#  411,
#  360,
#  328,
#  383,
#  405,
#  123,
#  420,
#  224,
#  388,
#  397,
#  425,
#  373,
#  365,
#  371,
#  311,
#  396,
#  345,
#  399,
#  400,
#  78,
#  280,
#  330,
#  403,
#  379,
#  380,
#  94,
#  394,
#  419,
#  339,
#  293,
#  344,
#  390,
#  84,
#  359,
#  372,
#  377,
#  346,
#  389,
#  386,
#  308,
#  277,
#  382,
#  368,
#  402,
#  292,
#  298,
#  366,
#  352,
#  363,
#  322,
#  361,
#  91,
#  364,
#  341,
#  385,
#  355,
#  305,
#  321,
#  262,
#  93,
#  375,
#  387,
#  356,
#  253,
#  285,
#  391,
#  353,
#  367,
#  90,
#  295,
#  378,
#  256,
#  338,
#  331,
#  69,
#  105,
#  85,
#  358,
#  343,
#  319,
#  271,
#  113,
#  350,
#  406,
#  340,
#  393,
#  247,
#  334,
#  351,
#  342,
#  302,
#  329,
#  354,
#  98,
#  301,
#  115,
#  384,
#  208,
#  72,
#  376,
#  92,
#  258,
#  362,
#  74,
#  417,
#  99,
#  263,
#  88,
#  279,
#  101,
#  395,
# ...

# %%
df['Crossing'].unique().tolist()
# Out:
# [85,
#  84,
#  13,
#  94,
#  71,
#  79,
#  17,
#  78,
#  18,
#  53,
#  76,
#  58,
#  14,
#  15,
#  75,
#  66,
#  70,
#  68,
#  91,
#  82,
#  20,
#  12,
#  30,
#  77,
#  88,
#  83,
#  93,
#  90,
#  87,
#  81,
#  73,
#  11,
#  54,
#  62,
#  86,
#  80,
#  55,
#  42,
#  57,
#  65,
#  63,
#  64,
#  52,
#  40,
#  69,
#  47,
#  60,
#  9,
#  16,
#  44,
#  72,
#  50,
#  56,
#  46,
#  89,
#  34,
#  45,
#  74,
#  49,
#  67,
#  24,
#  35,
#  36,
#  61,
#  19,
#  27,
#  25,
#  10,
#  51,
#  38,
#  43,
#  59,
#  39,
#  48,
#  23,
#  8,
#  28,
#  92,
#  41,
#  29,
#  32,
#  22,
#  26,
#  37,
#  33,
#  31,
#  21,
#  7,
#  6]

# %%
df['Finishing'].unique().tolist()
# Out:
# [95,
#  11,
#  82,
#  87,
#  94,
#  91,
#  13,
#  14,
#  52,
#  90,
#  64,
#  88,
#  65,
#  85,
#  66,
#  84,
#  10,
#  22,
#  76,
#  81,
#  56,
#  79,
#  57,
#  45,
#  77,
#  63,
#  86,
#  80,
#  15,
#  33,
#  67,
#  12,
#  72,
#  92,
#  93,
#  51,
#  46,
#  60,
#  75,
#  55,
#  73,
#  83,
#  50,
#  42,
#  39,
#  40,
#  9,
#  68,
#  48,
#  37,
#  70,
#  78,
#  69,
#  8,
#  53,
#  89,
#  25,
#  62,
#  71,
#  74,
#  44,
#  26,
#  19,
#  32,
#  18,
#  61,
#  58,
#  30,
#  54,
#  36,
#  29,
#  16,
#  38,
#  59,
#  27,
#  34,
#  47,
#  20,
#  31,
#  49,
#  43,
#  41,
#  28,
#  5,
#  7,
#  6,
#  21,
#  17,
#  35,
#  23,
#  24,
#  4,
#  3]

# %%
df['Heading Accuracy'].unique().tolist()
# Out:
# [70,
#  90,
#  15,
#  55,
#  62,
#  85,
#  59,
#  19,
#  73,
#  11,
#  87,
#  84,
#  80,
#  13,
#  25,
#  91,
#  92,
#  78,
#  46,
#  54,
#  72,
#  64,
#  14,
#  10,
#  61,
#  58,
#  83,
#  38,
#  69,
#  51,
#  67,
#  86,
#  75,
#  68,
#  16,
#  81,
#  21,
#  79,
#  53,
#  65,
#  82,
#  12,
#  42,
#  48,
#  88,
#  66,
#  76,
#  74,
#  52,
#  23,
#  40,
#  49,
#  60,
#  44,
#  20,
#  37,
#  71,
#  17,
#  45,
#  77,
#  50,
#  63,
#  43,
#  39,
#  57,
#  56,
#  47,
#  24,
#  18,
#  31,
#  28,
#  35,
#  34,
#  41,
#  36,
#  93,
#  7,
#  30,
#  89,
#  8,
#  26,
#  33,
#  27,
#  32,
#  22,
#  29,
#  9,
#  5,
#  6]

# %%
df['Short Passing'].unique().tolist()
# Out:
# [91,
#  82,
#  43,
#  94,
#  87,
#  84,
#  45,
#  83,
#  61,
#  79,
#  85,
#  33,
#  55,
#  86,
#  57,
#  81,
#  42,
#  74,
#  93,
#  88,
#  30,
#  65,
#  89,
#  77,
#  32,
#  50,
#  80,
#  78,
#  90,
#  69,
#  40,
#  92,
#  75,
#  73,
#  34,
#  76,
#  35,
#  70,
#  37,
#  23,
#  44,
#  38,
#  48,
#  26,
#  60,
#  25,
#  46,
#  28,
#  24,
#  36,
#  51,
#  17,
#  18,
#  39,
#  71,
#  67,
#  27,
#  72,
#  66,
#  20,
#  31,
#  68,
#  29,
#  11,
#  64,
#  62,
#  41,
#  63,
#  19,
#  54,
#  16,
#  22,
#  49,
#  59,
#  56,
#  14,
#  58,
#  15,
#  21,
#  52,
#  53,
#  12,
#  47,
#  13,
#  8,
#  7]

# %%
df['Volleys'].unique().tolist()
# Out:
# [88,
#  86,
#  13,
#  82,
#  87,
#  89,
#  79,
#  20,
#  83,
#  14,
#  45,
#  75,
#  63,
#  12,
#  11,
#  69,
#  67,
#  56,
#  18,
#  85,
#  62,
#  70,
#  32,
#  40,
#  47,
#  81,
#  44,
#  84,
#  78,
#  76,
#  90,
#  49,
#  42,
#  64,
#  57,
#  60,
#  8,
#  72,
#  71,
#  59,
#  74,
#  80,
#  73,
#  37,
#  31,
#  38,
#  61,
#  10,
#  77,
#  68,
#  58,
#  66,
#  30,
#  33,
#  65,
#  27,
#  51,
#  15,
#  16,
#  50,
#  43,
#  35,
#  24,
#  17,
#  34,
#  28,
#  9,
#  39,
#  52,
#  46,
#  22,
#  19,
#  53,
#  55,
#  48,
#  54,
#  23,
#  5,
#  41,
#  25,
#  21,
#  36,
#  26,
#  29,
#  6,
#  7,
#  4,
#  3]

# %%
df['Skill'].unique().tolist()
# Out:
# [470,
#  414,
#  109,
#  441,
#  448,
#  407,
#  406,
#  138,
#  394,
#  144,
#  363,
#  391,
#  369,
#  110,
#  160,
#  404,
#  381,
#  397,
#  387,
#  336,
#  400,
#  436,
#  157,
#  395,
#  100,
#  262,
#  427,
#  432,
#  429,
#  380,
#  426,
#  411,
#  358,
#  351,
#  433,
#  365,
#  403,
#  98,
#  276,
#  386,
#  383,
#  99,
#  413,
#  115,
#  341,
#  375,
#  143,
#  359,
#  309,
#  435,
#  330,
#  325,
#  355,
#  96,
#  420,
#  412,
#  388,
#  319,
#  269,
#  399,
#  106,
#  402,
#  425,
#  297,
#  312,
#  418,
#  372,
#  352,
#  439,
#  409,
#  349,
#  116,
#  371,
#  428,
#  104,
#  345,
#  430,
#  295,
#  405,
#  440,
#  422,
#  252,
#  401,
#  417,
#  396,
#  233,
#  377,
#  251,
#  382,
#  368,
#  84,
#  356,
#  342,
#  410,
#  271,
#  350,
#  83,
#  126,
#  103,
#  370,
#  362,
#  343,
#  328,
#  344,
#  415,
#  378,
#  275,
#  416,
#  119,
#  127,
#  373,
#  384,
#  77,
#  393,
#  348,
#  317,
#  408,
#  376,
#  300,
#  220,
#  89,
#  107,
#  334,
#  72,
#  390,
#  419,
# ...

# %%
df['Dribbling'].unique().tolist()
# Out:
# [96,
#  88,
#  12,
#  95,
#  85,
#  90,
#  27,
#  92,
#  21,
#  70,
#  91,
#  69,
#  13,
#  30,
#  87,
#  65,
#  79,
#  83,
#  23,
#  80,
#  18,
#  93,
#  77,
#  63,
#  76,
#  16,
#  59,
#  81,
#  11,
#  84,
#  10,
#  75,
#  78,
#  55,
#  15,
#  86,
#  66,
#  67,
#  28,
#  57,
#  64,
#  82,
#  62,
#  19,
#  53,
#  72,
#  50,
#  26,
#  43,
#  89,
#  73,
#  20,
#  14,
#  68,
#  71,
#  74,
#  22,
#  54,
#  56,
#  61,
#  9,
#  24,
#  60,
#  25,
#  8,
#  17,
#  47,
#  58,
#  46,
#  42,
#  51,
#  52,
#  49,
#  44,
#  35,
#  48,
#  39,
#  29,
#  40,
#  45,
#  34,
#  31,
#  33,
#  38,
#  41,
#  32,
#  7,
#  37,
#  36,
#  5,
#  6]

# %%
df['Curve'].unique().tolist()
# Out:
# [93,
#  81,
#  13,
#  85,
#  88,
#  79,
#  83,
#  19,
#  18,
#  60,
#  76,
#  63,
#  14,
#  74,
#  77,
#  49,
#  15,
#  80,
#  12,
#  28,
#  86,
#  84,
#  82,
#  61,
#  71,
#  11,
#  66,
#  16,
#  89,
#  70,
#  21,
#  46,
#  78,
#  67,
#  58,
#  65,
#  48,
#  34,
#  90,
#  59,
#  55,
#  87,
#  62,
#  9,
#  56,
#  36,
#  30,
#  32,
#  73,
#  69,
#  68,
#  75,
#  45,
#  10,
#  72,
#  64,
#  41,
#  23,
#  47,
#  20,
#  51,
#  25,
#  44,
#  17,
#  54,
#  57,
#  53,
#  33,
#  40,
#  50,
#  39,
#  35,
#  52,
#  42,
#  37,
#  43,
#  26,
#  31,
#  92,
#  91,
#  29,
#  94,
#  27,
#  38,
#  22,
#  24,
#  8,
#  6,
#  7,
#  5,
#  4]

# %%
df['FK Accuracy'].unique().tolist()
# Out:
# [94,
#  76,
#  14,
#  83,
#  89,
#  85,
#  69,
#  18,
#  63,
#  12,
#  70,
#  64,
#  74,
#  20,
#  11,
#  73,
#  49,
#  61,
#  88,
#  68,
#  28,
#  79,
#  84,
#  48,
#  67,
#  38,
#  87,
#  53,
#  65,
#  15,
#  31,
#  78,
#  82,
#  10,
#  51,
#  59,
#  19,
#  47,
#  52,
#  57,
#  43,
#  13,
#  77,
#  54,
#  75,
#  86,
#  55,
#  30,
#  62,
#  32,
#  58,
#  93,
#  8,
#  66,
#  71,
#  81,
#  92,
#  44,
#  17,
#  60,
#  40,
#  16,
#  72,
#  46,
#  35,
#  45,
#  29,
#  21,
#  56,
#  80,
#  24,
#  22,
#  39,
#  42,
#  26,
#  41,
#  9,
#  37,
#  27,
#  50,
#  33,
#  25,
#  36,
#  91,
#  34,
#  23,
#  7,
#  6,
#  90,
#  5]

# %%
df['Long Passing'].unique().tolist()
# Out:
# [91,
#  77,
#  40,
#  93,
#  81,
#  70,
#  75,
#  44,
#  63,
#  86,
#  71,
#  84,
#  35,
#  59,
#  73,
#  83,
#  64,
#  69,
#  79,
#  82,
#  68,
#  89,
#  76,
#  80,
#  87,
#  37,
#  65,
#  36,
#  50,
#  53,
#  78,
#  47,
#  74,
#  48,
#  31,
#  85,
#  24,
#  55,
#  90,
#  54,
#  62,
#  32,
#  49,
#  66,
#  67,
#  51,
#  28,
#  46,
#  52,
#  72,
#  56,
#  41,
#  45,
#  22,
#  88,
#  61,
#  33,
#  12,
#  60,
#  17,
#  27,
#  29,
#  23,
#  38,
#  16,
#  58,
#  34,
#  25,
#  39,
#  21,
#  30,
#  42,
#  43,
#  57,
#  20,
#  26,
#  18,
#  19,
#  13,
#  15,
#  11,
#  14,
#  9,
#  10,
#  5,
#  8]

# %%
df['Ball Control'].unique().tolist()
# Out:
# [96,
#  92,
#  30,
#  95,
#  88,
#  89,
#  90,
#  77,
#  79,
#  23,
#  46,
#  83,
#  80,
#  85,
#  94,
#  40,
#  84,
#  16,
#  74,
#  91,
#  87,
#  82,
#  78,
#  19,
#  61,
#  22,
#  34,
#  38,
#  81,
#  25,
#  86,
#  76,
#  69,
#  28,
#  93,
#  75,
#  35,
#  60,
#  63,
#  73,
#  18,
#  71,
#  15,
#  21,
#  72,
#  14,
#  65,
#  20,
#  24,
#  27,
#  70,
#  33,
#  17,
#  62,
#  64,
#  9,
#  68,
#  67,
#  32,
#  26,
#  66,
#  52,
#  11,
#  57,
#  58,
#  29,
#  12,
#  37,
#  10,
#  36,
#  13,
#  31,
#  55,
#  59,
#  39,
#  54,
#  56,
#  48,
#  44,
#  51,
#  50,
#  47,
#  49,
#  53,
#  5,
#  42,
#  8,
#  45,
#  43,
#  41,
#  7]

# %%
df['Movement'].unique().tolist()
# Out:
# [451,
#  431,
#  307,
#  398,
#  453,
#  407,
#  460,
#  268,
#  458,
#  254,
#  354,
#  343,
#  284,
#  286,
#  388,
#  378,
#  424,
#  464,
#  420,
#  399,
#  437,
#  322,
#  367,
#  272,
#  328,
#  448,
#  332,
#  425,
#  435,
#  391,
#  434,
#  400,
#  331,
#  349,
#  429,
#  416,
#  312,
#  326,
#  418,
#  419,
#  417,
#  386,
#  321,
#  409,
#  374,
#  304,
#  403,
#  351,
#  401,
#  365,
#  414,
#  292,
#  323,
#  299,
#  433,
#  350,
#  348,
#  413,
#  320,
#  281,
#  427,
#  353,
#  364,
#  410,
#  428,
#  316,
#  381,
#  442,
#  375,
#  288,
#  395,
#  385,
#  251,
#  319,
#  444,
#  383,
#  298,
#  411,
#  412,
#  415,
#  393,
#  397,
#  443,
#  423,
#  387,
#  422,
#  327,
#  390,
#  362,
#  352,
#  406,
#  277,
#  361,
#  421,
#  396,
#  384,
#  450,
#  338,
#  363,
#  359,
#  287,
#  297,
#  430,
#  382,
#  377,
#  380,
#  438,
#  449,
#  257,
#  371,
#  339,
#  341,
#  404,
#  345,
#  394,
#  295,
#  246,
#  265,
#  258,
#  366,
#  294,
#  314,
#  266,
#  405,
#  218,
# ...

# %%
df['Acceleration'].unique().tolist()
# Out:
# [91,
#  87,
#  43,
#  77,
#  94,
#  56,
#  96,
#  38,
#  72,
#  95,
#  60,
#  42,
#  54,
#  79,
#  89,
#  64,
#  66,
#  51,
#  73,
#  57,
#  80,
#  86,
#  85,
#  78,
#  40,
#  82,
#  76,
#  65,
#  68,
#  90,
#  48,
#  46,
#  88,
#  70,
#  83,
#  84,
#  93,
#  52,
#  74,
#  92,
#  55,
#  58,
#  59,
#  67,
#  81,
#  62,
#  44,
#  71,
#  69,
#  50,
#  53,
#  45,
#  49,
#  75,
#  41,
#  61,
#  63,
#  35,
#  47,
#  34,
#  36,
#  37,
#  39,
#  30,
#  97,
#  31,
#  33,
#  32,
#  27,
#  28,
#  26,
#  29,
#  25,
#  17,
#  19,
#  24,
#  15,
#  23,
#  21,
#  20,
#  22,
#  16,
#  18,
#  13,
#  14]

# %%
df['Sprint Speed'].unique().tolist()
# Out:
# [80,
#  91,
#  60,
#  76,
#  89,
#  78,
#  92,
#  47,
#  96,
#  50,
#  79,
#  93,
#  69,
#  52,
#  72,
#  70,
#  90,
#  66,
#  82,
#  63,
#  55,
#  77,
#  86,
#  81,
#  83,
#  85,
#  65,
#  68,
#  53,
#  43,
#  94,
#  62,
#  58,
#  61,
#  87,
#  64,
#  67,
#  54,
#  88,
#  75,
#  95,
#  73,
#  49,
#  84,
#  56,
#  44,
#  74,
#  51,
#  57,
#  46,
#  59,
#  71,
#  37,
#  34,
#  33,
#  42,
#  30,
#  35,
#  48,
#  39,
#  45,
#  40,
#  18,
#  38,
#  41,
#  27,
#  32,
#  29,
#  28,
#  36,
#  26,
#  31,
#  22,
#  25,
#  23,
#  15,
#  20,
#  17,
#  16,
#  24,
#  19,
#  21,
#  12,
#  14]

# %%
df['Agility'].unique().tolist()
# Out:
# [91,
#  87,
#  67,
#  78,
#  96,
#  77,
#  40,
#  92,
#  37,
#  61,
#  93,
#  51,
#  79,
#  84,
#  94,
#  82,
#  60,
#  69,
#  47,
#  52,
#  63,
#  74,
#  59,
#  66,
#  86,
#  85,
#  57,
#  55,
#  76,
#  75,
#  73,
#  62,
#  72,
#  90,
#  68,
#  64,
#  80,
#  56,
#  48,
#  83,
#  41,
#  81,
#  54,
#  88,
#  33,
#  65,
#  49,
#  71,
#  89,
#  45,
#  70,
#  43,
#  50,
#  32,
#  42,
#  39,
#  58,
#  36,
#  34,
#  53,
#  46,
#  95,
#  44,
#  38,
#  21,
#  29,
#  35,
#  31,
#  19,
#  26,
#  30,
#  22,
#  28,
#  24,
#  25,
#  23,
#  27,
#  14,
#  18,
#  15,
#  20]

# %%
df['Reactions'].unique().tolist()
# Out:
# [94,
#  95,
#  88,
#  91,
#  93,
#  92,
#  86,
#  89,
#  87,
#  84,
#  90,
#  83,
#  85,
#  82,
#  81,
#  79,
#  80,
#  74,
#  75,
#  78,
#  77,
#  73,
#  76,
#  71,
#  70,
#  68,
#  72,
#  66,
#  69,
#  65,
#  67,
#  64,
#  59,
#  60,
#  62,
#  63,
#  61,
#  58,
#  57,
#  56,
#  50,
#  54,
#  53,
#  55,
#  52,
#  32,
#  49,
#  48,
#  45,
#  51,
#  46,
#  47,
#  37,
#  34,
#  44,
#  40,
#  38,
#  43,
#  41,
#  35,
#  42,
#  33,
#  39,
#  31,
#  36,
#  30,
#  24,
#  29,
#  28]

# %%
df['Balance'].unique().tolist()
# Out:
# [95,
#  71,
#  49,
#  76,
#  83,
#  82,
#  91,
#  37,
#  43,
#  53,
#  86,
#  66,
#  45,
#  35,
#  69,
#  94,
#  92,
#  84,
#  90,
#  48,
#  73,
#  36,
#  41,
#  93,
#  74,
#  60,
#  79,
#  65,
#  78,
#  61,
#  57,
#  50,
#  68,
#  51,
#  54,
#  77,
#  81,
#  39,
#  75,
#  58,
#  87,
#  85,
#  63,
#  38,
#  88,
#  67,
#  72,
#  62,
#  80,
#  44,
#  46,
#  42,
#  55,
#  40,
#  70,
#  32,
#  89,
#  52,
#  59,
#  47,
#  64,
#  27,
#  56,
#  30,
#  31,
#  25,
#  34,
#  29,
#  24,
#  96,
#  33,
#  28,
#  20,
#  23,
#  22,
#  26,
#  21,
#  17,
#  97,
#  19,
#  12,
#  18]

# %%
df['Power'].unique().tolist()
# Out:
# [389,
#  444,
#  268,
#  408,
#  357,
#  420,
#  393,
#  240,
#  404,
#  402,
#  406,
#  437,
#  249,
#  284,
#  400,
#  403,
#  358,
#  381,
#  382,
#  273,
#  424,
#  264,
#  316,
#  361,
#  355,
#  328,
#  370,
#  350,
#  365,
#  348,
#  411,
#  395,
#  385,
#  257,
#  337,
#  250,
#  379,
#  371,
#  409,
#  223,
#  398,
#  388,
#  241,
#  347,
#  308,
#  426,
#  378,
#  343,
#  341,
#  262,
#  325,
#  345,
#  359,
#  399,
#  421,
#  396,
#  315,
#  253,
#  368,
#  336,
#  340,
#  366,
#  387,
#  369,
#  375,
#  260,
#  326,
#  346,
#  373,
#  412,
#  364,
#  279,
#  376,
#  372,
#  415,
#  356,
#  333,
#  338,
#  342,
#  410,
#  407,
#  430,
#  394,
#  354,
#  331,
#  239,
#  234,
#  392,
#  270,
#  422,
#  374,
#  360,
#  391,
#  300,
#  335,
#  242,
#  327,
#  215,
#  397,
#  321,
#  390,
#  339,
#  383,
#  265,
#  288,
#  224,
#  351,
#  252,
#  429,
#  416,
#  380,
#  413,
#  377,
#  405,
#  349,
#  232,
#  386,
#  362,
#  192,
#  320,
#  251,
#  329,
#  271,
#  237,
#  427,
# ...

# %%
df['Shot Power'].unique().tolist()
# Out:
# [86,
#  94,
#  59,
#  91,
#  80,
#  89,
#  64,
#  66,
#  81,
#  84,
#  88,
#  56,
#  68,
#  79,
#  78,
#  71,
#  82,
#  70,
#  55,
#  76,
#  61,
#  83,
#  51,
#  52,
#  90,
#  87,
#  62,
#  72,
#  77,
#  74,
#  50,
#  57,
#  58,
#  85,
#  60,
#  75,
#  67,
#  65,
#  93,
#  46,
#  54,
#  69,
#  41,
#  73,
#  40,
#  53,
#  95,
#  43,
#  63,
#  42,
#  48,
#  31,
#  44,
#  37,
#  49,
#  39,
#  45,
#  38,
#  47,
#  30,
#  33,
#  25,
#  34,
#  36,
#  28,
#  27,
#  32,
#  26,
#  35,
#  23,
#  22,
#  29,
#  20,
#  24,
#  21,
#  18]

# %%
df['Jumping'].unique().tolist()
# Out:
# [68,
#  95,
#  78,
#  63,
#  62,
#  84,
#  69,
#  52,
#  77,
#  79,
#  90,
#  86,
#  87,
#  93,
#  57,
#  75,
#  66,
#  82,
#  56,
#  32,
#  51,
#  76,
#  72,
#  81,
#  74,
#  71,
#  67,
#  65,
#  73,
#  64,
#  70,
#  80,
#  85,
#  37,
#  89,
#  60,
#  49,
#  50,
#  83,
#  58,
#  53,
#  59,
#  88,
#  38,
#  92,
#  34,
#  61,
#  46,
#  43,
#  36,
#  91,
#  39,
#  45,
#  42,
#  40,
#  54,
#  33,
#  55,
#  31,
#  44,
#  35,
#  47,
#  48,
#  30,
#  41,
#  94,
#  28,
#  29,
#  27,
#  24,
#  19,
#  26,
#  17,
#  15,
#  22]

# %%
df['Stamina'].unique().tolist()
# Out:
# [72,
#  84,
#  41,
#  89,
#  81,
#  76,
#  85,
#  32,
#  86,
#  35,
#  75,
#  88,
#  90,
#  38,
#  43,
#  78,
#  79,
#  96,
#  95,
#  70,
#  82,
#  77,
#  93,
#  94,
#  87,
#  39,
#  54,
#  80,
#  45,
#  83,
#  69,
#  65,
#  73,
#  91,
#  34,
#  66,
#  71,
#  92,
#  62,
#  67,
#  64,
#  63,
#  68,
#  36,
#  61,
#  74,
#  42,
#  40,
#  23,
#  44,
#  31,
#  57,
#  20,
#  37,
#  29,
#  30,
#  56,
#  60,
#  52,
#  48,
#  58,
#  25,
#  51,
#  26,
#  27,
#  59,
#  28,
#  53,
#  33,
#  49,
#  97,
#  55,
#  50,
#  46,
#  24,
#  21,
#  22,
#  15,
#  47,
#  17,
#  19,
#  16,
#  18,
#  14,
#  12]

# %%
df['Strength'].unique().tolist()
# Out:
# [69,
#  78,
#  74,
#  50,
#  86,
#  75,
#  76,
#  92,
#  70,
#  91,
#  80,
#  85,
#  65,
#  72,
#  67,
#  60,
#  84,
#  71,
#  94,
#  63,
#  73,
#  62,
#  54,
#  81,
#  64,
#  87,
#  58,
#  43,
#  77,
#  66,
#  53,
#  89,
#  68,
#  46,
#  44,
#  61,
#  79,
#  88,
#  59,
#  83,
#  55,
#  34,
#  82,
#  95,
#  56,
#  37,
#  90,
#  57,
#  93,
#  49,
#  39,
#  51,
#  52,
#  40,
#  48,
#  41,
#  47,
#  35,
#  42,
#  33,
#  45,
#  32,
#  38,
#  30,
#  31,
#  36,
#  29,
#  27,
#  24,
#  28,
#  16,
#  97,
#  96,
#  20,
#  25,
#  26,
#  23]

# %%
df['Long Shots'].unique().tolist()
# Out:
# [94,
#  93,
#  12,
#  91,
#  84,
#  85,
#  14,
#  79,
#  10,
#  64,
#  78,
#  81,
#  17,
#  16,
#  65,
#  87,
#  18,
#  86,
#  19,
#  15,
#  82,
#  63,
#  74,
#  76,
#  47,
#  89,
#  70,
#  90,
#  77,
#  13,
#  49,
#  54,
#  88,
#  80,
#  53,
#  58,
#  51,
#  73,
#  66,
#  75,
#  83,
#  30,
#  46,
#  35,
#  71,
#  61,
#  72,
#  69,
#  43,
#  48,
#  62,
#  41,
#  60,
#  11,
#  26,
#  57,
#  59,
#  68,
#  67,
#  7,
#  27,
#  56,
#  20,
#  52,
#  92,
#  50,
#  22,
#  40,
#  39,
#  44,
#  31,
#  42,
#  9,
#  6,
#  55,
#  28,
#  23,
#  38,
#  24,
#  25,
#  34,
#  36,
#  29,
#  4,
#  8,
#  45,
#  33,
#  37,
#  21,
#  32,
#  5]

# %%
df['Mentality'].unique().tolist()
# Out:
# [347,
#  353,
#  140,
#  408,
#  356,
#  391,
#  376,
#  341,
#  171,
#  358,
#  396,
#  122,
#  188,
#  363,
#  414,
#  332,
#  386,
#  379,
#  348,
#  172,
#  382,
#  123,
#  294,
#  378,
#  313,
#  371,
#  331,
#  412,
#  345,
#  377,
#  161,
#  306,
#  387,
#  339,
#  135,
#  360,
#  138,
#  369,
#  359,
#  170,
#  361,
#  321,
#  397,
#  394,
#  385,
#  366,
#  162,
#  337,
#  362,
#  344,
#  319,
#  315,
#  144,
#  336,
#  340,
#  373,
#  398,
#  324,
#  300,
#  338,
#  384,
#  139,
#  364,
#  372,
#  134,
#  354,
#  342,
#  308,
#  322,
#  383,
#  263,
#  149,
#  304,
#  367,
#  357,
#  390,
#  291,
#  279,
#  310,
#  388,
#  375,
#  349,
#  351,
#  365,
#  133,
#  334,
#  303,
#  380,
#  153,
#  392,
#  169,
#  318,
#  350,
#  352,
#  401,
#  302,
#  325,
#  346,
#  132,
#  399,
#  281,
#  335,
#  403,
#  307,
#  368,
#  141,
#  126,
#  328,
#  245,
#  131,
#  320,
#  127,
#  421,
#  400,
#  137,
#  374,
#  305,
#  92,
#  316,
#  311,
#  120,
#  389,
#  145,
#  355,
#  148,
# ...

# %%
df['Aggression'].unique().tolist()
# Out:
# [44,
#  63,
#  34,
#  76,
#  51,
#  81,
#  27,
#  62,
#  43,
#  83,
#  75,
#  91,
#  23,
#  29,
#  90,
#  65,
#  59,
#  89,
#  48,
#  38,
#  25,
#  87,
#  54,
#  60,
#  73,
#  74,
#  69,
#  85,
#  70,
#  86,
#  32,
#  40,
#  31,
#  77,
#  84,
#  80,
#  78,
#  79,
#  71,
#  56,
#  42,
#  30,
#  61,
#  58,
#  28,
#  82,
#  46,
#  52,
#  36,
#  92,
#  55,
#  35,
#  67,
#  37,
#  72,
#  57,
#  50,
#  64,
#  39,
#  47,
#  20,
#  68,
#  15,
#  66,
#  33,
#  93,
#  88,
#  22,
#  24,
#  45,
#  17,
#  18,
#  26,
#  21,
#  11,
#  41,
#  53,
#  19,
#  12,
#  49,
#  94,
#  16,
#  95,
#  13,
#  14,
#  96,
#  10,
#  9]

# %%
df['Interceptions'].unique().tolist()
# Out:
# [40,
#  29,
#  19,
#  66,
#  36,
#  49,
#  55,
#  11,
#  38,
#  22,
#  90,
#  35,
#  87,
#  15,
#  30,
#  39,
#  88,
#  24,
#  91,
#  82,
#  42,
#  27,
#  41,
#  79,
#  74,
#  58,
#  20,
#  85,
#  48,
#  83,
#  64,
#  21,
#  50,
#  81,
#  78,
#  28,
#  86,
#  26,
#  34,
#  52,
#  37,
#  80,
#  25,
#  56,
#  23,
#  47,
#  45,
#  77,
#  84,
#  44,
#  53,
#  18,
#  46,
#  72,
#  61,
#  89,
#  54,
#  63,
#  65,
#  73,
#  16,
#  32,
#  76,
#  59,
#  13,
#  70,
#  31,
#  69,
#  33,
#  17,
#  75,
#  68,
#  60,
#  51,
#  71,
#  12,
#  57,
#  10,
#  43,
#  67,
#  14,
#  9,
#  62,
#  8,
#  7,
#  6,
#  4,
#  5,
#  3]

# %%
df['Positioning'].unique().tolist()
# Out:
# [93,
#  95,
#  11,
#  88,
#  87,
#  94,
#  91,
#  13,
#  47,
#  92,
#  72,
#  12,
#  90,
#  73,
#  80,
#  85,
#  20,
#  35,
#  76,
#  89,
#  83,
#  77,
#  54,
#  70,
#  86,
#  16,
#  28,
#  14,
#  84,
#  78,
#  10,
#  75,
#  52,
#  71,
#  81,
#  64,
#  56,
#  15,
#  82,
#  79,
#  44,
#  30,
#  59,
#  7,
#  68,
#  38,
#  48,
#  67,
#  24,
#  26,
#  34,
#  69,
#  74,
#  32,
#  66,
#  62,
#  65,
#  51,
#  18,
#  31,
#  9,
#  25,
#  49,
#  55,
#  63,
#  27,
#  61,
#  17,
#  39,
#  58,
#  29,
#  50,
#  40,
#  19,
#  8,
#  42,
#  60,
#  57,
#  37,
#  45,
#  43,
#  53,
#  5,
#  4,
#  36,
#  6,
#  46,
#  41,
#  23,
#  22,
#  33,
#  21,
#  3,
#  2]

# %%
df['Vision'].unique().tolist()
# Out:
# [95,
#  82,
#  65,
#  94,
#  90,
#  79,
#  84,
#  66,
#  80,
#  70,
#  85,
#  44,
#  87,
#  71,
#  83,
#  41,
#  52,
#  86,
#  68,
#  50,
#  77,
#  48,
#  88,
#  30,
#  61,
#  74,
#  59,
#  73,
#  72,
#  64,
#  91,
#  78,
#  63,
#  57,
#  89,
#  62,
#  56,
#  69,
#  42,
#  67,
#  27,
#  76,
#  81,
#  55,
#  75,
#  60,
#  49,
#  45,
#  58,
#  22,
#  53,
#  46,
#  25,
#  43,
#  51,
#  40,
#  93,
#  33,
#  31,
#  34,
#  35,
#  39,
#  47,
#  21,
#  32,
#  28,
#  37,
#  36,
#  38,
#  54,
#  24,
#  23,
#  14,
#  11,
#  15,
#  26,
#  19,
#  18,
#  12,
#  20,
#  17,
#  10,
#  29,
#  13,
#  16,
#  9]

# %%
df['Penalties'].unique().tolist()
# Out:
# [75,
#  84,
#  11,
#  92,
#  88,
#  83,
#  23,
#  70,
#  25,
#  62,
#  71,
#  66,
#  27,
#  47,
#  69,
#  54,
#  44,
#  86,
#  17,
#  90,
#  33,
#  87,
#  73,
#  60,
#  55,
#  68,
#  91,
#  72,
#  50,
#  78,
#  18,
#  82,
#  40,
#  29,
#  45,
#  43,
#  64,
#  24,
#  59,
#  46,
#  56,
#  81,
#  67,
#  49,
#  61,
#  74,
#  58,
#  63,
#  79,
#  38,
#  80,
#  32,
#  20,
#  76,
#  77,
#  41,
#  19,
#  26,
#  85,
#  21,
#  52,
#  34,
#  53,
#  65,
#  57,
#  16,
#  42,
#  89,
#  15,
#  13,
#  14,
#  22,
#  51,
#  37,
#  9,
#  48,
#  12,
#  31,
#  36,
#  39,
#  10,
#  30,
#  35,
#  28,
#  8,
#  7,
#  6]

# %%
df['Composure'].unique().tolist()
# Out:
# [96,
#  95,
#  68,
#  91,
#  93,
#  88,
#  90,
#  65,
#  84,
#  70,
#  66,
#  80,
#  85,
#  69,
#  82,
#  89,
#  81,
#  87,
#  83,
#  86,
#  67,
#  92,
#  94,
#  57,
#  78,
#  79,
#  75,
#  45,
#  61,
#  76,
#  58,
#  62,
#  77,
#  74,
#  59,
#  55,
#  48,
#  40,
#  64,
#  73,
#  39,
#  71,
#  72,
#  63,
#  60,
#  52,
#  53,
#  56,
#  44,
#  54,
#  41,
#  32,
#  49,
#  46,
#  31,
#  51,
#  50,
#  25,
#  18,
#  38,
#  30,
#  24,
#  21,
#  36,
#  33,
#  26,
#  23,
#  47,
#  22,
#  28,
#  34,
#  35,
#  37,
#  43,
#  27,
#  12,
#  42,
#  17,
#  29,
#  13,
#  19,
#  14,
#  16,
#  20,
#  15]

# %%
df['Defending'].unique().tolist()
# Out:
# [91,
#  84,
#  57,
#  186,
#  94,
#  96,
#  122,
#  50,
#  100,
#  48,
#  272,
#  259,
#  54,
#  38,
#  89,
#  263,
#  83,
#  147,
#  264,
#  245,
#  120,
#  52,
#  130,
#  267,
#  205,
#  162,
#  105,
#  241,
#  148,
#  248,
#  266,
#  194,
#  258,
#  117,
#  166,
#  56,
#  249,
#  92,
#  45,
#  214,
#  140,
#  99,
#  150,
#  59,
#  251,
#  262,
#  243,
#  195,
#  160,
#  40,
#  114,
#  236,
#  244,
#  231,
#  80,
#  123,
#  253,
#  132,
#  103,
#  257,
#  261,
#  98,
#  78,
#  209,
#  229,
#  230,
#  60,
#  101,
#  206,
#  242,
#  138,
#  61,
#  256,
#  171,
#  260,
#  226,
#  224,
#  44,
#  131,
#  113,
#  240,
#  77,
#  232,
#  225,
#  109,
#  228,
#  247,
#  93,
#  121,
#  238,
#  111,
#  128,
#  188,
#  173,
#  250,
#  255,
#  41,
#  144,
#  239,
#  217,
#  106,
#  165,
#  246,
#  235,
#  126,
#  118,
#  203,
#  234,
#  135,
#  215,
#  175,
#  192,
#  108,
#  39,
#  33,
#  151,
#  156,
#  174,
#  47,
#  216,
#  237,
#  102,
#  227,
#  161,
#  233,
#  67,
#  213,
#  75,
#  212,
# ...

# %%
df['Marking'].unique().tolist()
# Out:
# [32,
#  28,
#  27,
#  68,
#  35,
#  38,
#  15,
#  34,
#  25,
#  93,
#  42,
#  84,
#  20,
#  17,
#  47,
#  85,
#  30,
#  89,
#  82,
#  29,
#  56,
#  91,
#  72,
#  59,
#  79,
#  49,
#  83,
#  86,
#  50,
#  60,
#  94,
#  41,
#  57,
#  78,
#  63,
#  88,
#  90,
#  9,
#  58,
#  74,
#  39,
#  92,
#  45,
#  36,
#  44,
#  87,
#  70,
#  76,
#  53,
#  80,
#  67,
#  77,
#  12,
#  48,
#  55,
#  75,
#  81,
#  11,
#  64,
#  69,
#  14,
#  24,
#  52,
#  65,
#  19,
#  31,
#  13,
#  10,
#  66,
#  71,
#  54,
#  46,
#  22,
#  40,
#  18,
#  51,
#  37,
#  43,
#  61,
#  26,
#  73,
#  21,
#  7,
#  33,
#  62,
#  16,
#  23,
#  8,
#  6,
#  5,
#  4,
#  3]

# %%
df['Standing Tackle'].unique().tolist()
# Out:
# [35,
#  32,
#  12,
#  65,
#  30,
#  42,
#  43,
#  19,
#  34,
#  13,
#  93,
#  88,
#  18,
#  10,
#  24,
#  29,
#  53,
#  90,
#  84,
#  48,
#  15,
#  36,
#  89,
#  27,
#  73,
#  54,
#  41,
#  83,
#  59,
#  67,
#  87,
#  64,
#  14,
#  55,
#  75,
#  45,
#  33,
#  57,
#  21,
#  82,
#  50,
#  86,
#  80,
#  79,
#  31,
#  46,
#  85,
#  40,
#  44,
#  56,
#  20,
#  70,
#  76,
#  81,
#  71,
#  16,
#  68,
#  37,
#  38,
#  78,
#  39,
#  77,
#  11,
#  74,
#  28,
#  49,
#  47,
#  72,
#  61,
#  51,
#  22,
#  17,
#  52,
#  63,
#  23,
#  60,
#  25,
#  26,
#  9,
#  62,
#  58,
#  66,
#  69,
#  7,
#  8,
#  6,
#  5]

# %%
df['Sliding Tackle'].unique().tolist()
# Out:
# [24,
#  18,
#  53,
#  29,
#  19,
#  41,
#  16,
#  32,
#  10,
#  86,
#  38,
#  87,
#  11,
#  90,
#  47,
#  85,
#  79,
#  40,
#  8,
#  13,
#  22,
#  60,
#  49,
#  81,
#  88,
#  55,
#  33,
#  42,
#  14,
#  80,
#  36,
#  12,
#  52,
#  71,
#  46,
#  83,
#  65,
#  84,
#  34,
#  82,
#  77,
#  78,
#  74,
#  20,
#  43,
#  35,
#  69,
#  70,
#  30,
#  68,
#  45,
#  57,
#  44,
#  21,
#  75,
#  26,
#  51,
#  76,
#  39,
#  48,
#  28,
#  63,
#  59,
#  66,
#  72,
#  17,
#  67,
#  64,
#  31,
#  25,
#  15,
#  54,
#  58,
#  62,
#  56,
#  23,
#  37,
#  73,
#  50,
#  27,
#  9,
#  61,
#  7,
#  6,
#  4]

# %%
df['Goalkeeping'].unique().tolist()
# Out:
# [54,
#  58,
#  437,
#  56,
#  59,
#  51,
#  62,
#  439,
#  42,
#  67,
#  420,
#  440,
#  41,
#  46,
#  63,
#  60,
#  26,
#  435,
#  424,
#  43,
#  45,
#  52,
#  50,
#  47,
#  53,
#  44,
#  418,
#  15,
#  48,
#  416,
#  153,
#  413,
#  65,
#  64,
#  20,
#  423,
#  49,
#  55,
#  66,
#  40,
#  57,
#  421,
#  13,
#  39,
#  61,
#  419,
#  21,
#  409,
#  37,
#  406,
#  410,
#  36,
#  408,
#  34,
#  29,
#  405,
#  403,
#  402,
#  407,
#  16,
#  69,
#  391,
#  401,
#  398,
#  400,
#  22,
#  68,
#  396,
#  38,
#  78,
#  73,
#  399,
#  390,
#  393,
#  395,
#  397,
#  80,
#  70,
#  389,
#  394,
#  388,
#  27,
#  30,
#  75,
#  71,
#  386,
#  74,
#  378,
#  385,
#  384,
#  380,
#  392,
#  381,
#  10,
#  387,
#  383,
#  375,
#  382,
#  19,
#  379,
#  24,
#  369,
#  356,
#  368,
#  373,
#  370,
#  372,
#  72,
#  374,
#  376,
#  364,
#  25,
#  367,
#  17,
#  377,
#  371,
#  365,
#  352,
#  362,
#  359,
#  363,
#  366,
#  82,
#  35,
#  361,
#  358,
#  76,
#  294,
#  83,
#  357,
#  360,
#  355,
# ...

# %%
df['GK Diving'].unique().tolist()
# Out:
# [6,
#  7,
#  87,
#  15,
#  9,
#  14,
#  86,
#  13,
#  88,
#  10,
#  84,
#  11,
#  8,
#  5,
#  12,
#  90,
#  3,
#  27,
#  89,
#  80,
#  16,
#  85,
#  2,
#  82,
#  79,
#  83,
#  4,
#  81,
#  77,
#  18,
#  78,
#  17,
#  75,
#  74,
#  76,
#  73,
#  71,
#  72,
#  52,
#  68,
#  70,
#  54,
#  69,
#  32,
#  66,
#  65,
#  67,
#  61,
#  22,
#  64,
#  23,
#  40,
#  63,
#  55,
#  19,
#  50,
#  62,
#  58,
#  60,
#  59,
#  56,
#  57,
#  53,
#  51,
#  49,
#  46,
#  48,
#  47,
#  45]

# %%
df['GK Handling'].unique().tolist()
# Out:
# [11,
#  92,
#  13,
#  9,
#  6,
#  14,
#  88,
#  5,
#  85,
#  10,
#  89,
#  87,
#  8,
#  15,
#  12,
#  4,
#  82,
#  81,
#  3,
#  7,
#  25,
#  86,
#  83,
#  2,
#  80,
#  16,
#  77,
#  79,
#  78,
#  76,
#  84,
#  75,
#  72,
#  74,
#  71,
#  69,
#  73,
#  70,
#  67,
#  68,
#  65,
#  61,
#  62,
#  64,
#  41,
#  63,
#  66,
#  33,
#  22,
#  17,
#  57,
#  18,
#  54,
#  55,
#  59,
#  49,
#  19,
#  40,
#  60,
#  58,
#  43,
#  45,
#  53,
#  47,
#  56,
#  51,
#  52,
#  50,
#  48,
#  46]

# %%
df['GK Kicking'].unique().tolist()
# Out:
# [15,
#  78,
#  5,
#  12,
#  9,
#  85,
#  7,
#  88,
#  13,
#  16,
#  74,
#  91,
#  6,
#  10,
#  4,
#  93,
#  11,
#  73,
#  14,
#  75,
#  2,
#  31,
#  68,
#  76,
#  8,
#  80,
#  82,
#  3,
#  87,
#  72,
#  83,
#  77,
#  79,
#  81,
#  69,
#  71,
#  20,
#  67,
#  70,
#  64,
#  65,
#  63,
#  44,
#  60,
#  84,
#  54,
#  48,
#  61,
#  18,
#  66,
#  17,
#  59,
#  62,
#  90,
#  43,
#  38,
#  58,
#  57,
#  28,
#  40,
#  53,
#  23,
#  47,
#  46,
#  19,
#  51,
#  55,
#  52,
#  56,
#  22,
#  30,
#  25,
#  42,
#  35,
#  21,
#  49,
#  50,
#  36,
#  45]

# %%
df['GK Positioning'].unique().tolist()
# Out:
# [14,
#  90,
#  10,
#  15,
#  8,
#  11,
#  91,
#  88,
#  7,
#  12,
#  85,
#  86,
#  5,
#  89,
#  13,
#  6,
#  82,
#  4,
#  9,
#  87,
#  33,
#  84,
#  16,
#  83,
#  2,
#  3,
#  79,
#  81,
#  80,
#  76,
#  78,
#  19,
#  77,
#  17,
#  75,
#  74,
#  73,
#  71,
#  18,
#  72,
#  70,
#  69,
#  66,
#  68,
#  40,
#  64,
#  20,
#  32,
#  67,
#  62,
#  65,
#  63,
#  24,
#  23,
#  50,
#  55,
#  58,
#  51,
#  59,
#  56,
#  61,
#  57,
#  60,
#  46,
#  54,
#  53,
#  52,
#  47,
#  49,
#  48,
#  43,
#  45,
#  42,
#  38,
#  44,
#  41]

# %%
df['GK Reflexes'].unique().tolist()
# Out:
# [8,
#  11,
#  90,
#  13,
#  10,
#  14,
#  89,
#  6,
#  12,
#  88,
#  7,
#  9,
#  15,
#  5,
#  3,
#  37,
#  85,
#  86,
#  4,
#  16,
#  82,
#  83,
#  84,
#  87,
#  78,
#  80,
#  20,
#  18,
#  79,
#  81,
#  19,
#  77,
#  17,
#  2,
#  74,
#  71,
#  76,
#  73,
#  75,
#  72,
#  69,
#  46,
#  66,
#  51,
#  70,
#  34,
#  67,
#  23,
#  68,
#  45,
#  65,
#  21,
#  59,
#  54,
#  47,
#  61,
#  64,
#  63,
#  62,
#  60,
#  58,
#  56,
#  57,
#  55,
#  53,
#  50,
#  52,
#  49,
#  48,
#  44]

# %%
df['Total Stats'].unique().tolist()
# Out:
# [2231,
#  2221,
#  1413,
#  2304,
#  2175,
#  2195,
#  2211,
#  1389,
#  2147,
#  1442,
#  2112,
#  2203,
#  2220,
#  1325,
#  1515,
#  2111,
#  2258,
#  2118,
#  2169,
#  2269,
#  2154,
#  1534,
#  2172,
#  1317,
#  1734,
#  2105,
#  2150,
#  2288,
#  1986,
#  2124,
#  2127,
#  1983,
#  2303,
#  2171,
#  2128,
#  2208,
#  1380,
#  1830,
#  2021,
#  2072,
#  2168,
#  2252,
#  2316,
#  1361,
#  2057,
#  2117,
#  1449,
#  2133,
#  1933,
#  2235,
#  2119,
#  1991,
#  2040,
#  1366,
#  2060,
#  2065,
#  2224,
#  2093,
#  2225,
#  2095,
#  2058,
#  1988,
#  1813,
#  2149,
#  1330,
#  2071,
#  2086,
#  2096,
#  1930,
#  1962,
#  2034,
#  2191,
#  2026,
#  2170,
#  1946,
#  2185,
#  2001,
#  2031,
#  2037,
#  1372,
#  2019,
#  2178,
#  2179,
#  2188,
#  2090,
#  1315,
#  1967,
#  2023,
#  2048,
#  1875,
#  2267,
#  2181,
#  2120,
#  1761,
#  1458,
#  2083,
#  2039,
#  2115,
#  2027,
#  2282,
#  1947,
#  2183,
#  2163,
#  1697,
#  2148,
#  1821,
#  2255,
#  2213,
#  2197,
#  2080,
#  2176,
# ...

# %%
df['Base Stats'].unique().tolist()
# Out:
# [466,
#  464,
#  489,
#  485,
#  451,
#  457,
#  470,
#  490,
#  484,
#  455,
#  469,
#  463,
#  468,
#  497,
#  442,
#  439,
#  473,
#  452,
#  498,
#  449,
#  477,
#  401,
#  446,
#  447,
#  465,
#  430,
#  461,
#  422,
#  476,
#  460,
#  453,
#  467,
#  471,
#  399,
#  424,
#  441,
#  459,
#  438,
#  437,
#  454,
#  428,
#  445,
#  431,
#  474,
#  421,
#  435,
#  448,
#  475,
#  403,
#  444,
#  443,
#  419,
#  405,
#  420,
#  423,
#  396,
#  388,
#  482,
#  478,
#  385,
#  394,
#  480,
#  433,
#  450,
#  462,
#  456,
#  436,
#  434,
#  429,
#  400,
#  440,
#  425,
#  410,
#  458,
#  398,
#  413,
#  373,
#  406,
#  408,
#  472,
#  426,
#  407,
#  432,
#  427,
#  415,
#  481,
#  417,
#  372,
#  380,
#  418,
#  383,
#  414,
#  409,
#  412,
#  411,
#  386,
#  362,
#  402,
#  390,
#  404,
#  391,
#  416,
#  375,
#  389,
#  361,
#  397,
#  366,
#  392,
#  393,
#  382,
#  368,
#  387,
#  352,
#  376,
#  384,
#  378,
#  379,
#  341,
#  354,
#  369,
#  395,
#  357,
#  381,
#  377,
#  344,
# ...

# %%
df['W/F'].unique().tolist()
# Out:
# ['4 ★', '3 ★', '5 ★', '2 ★', '1 ★']

# %%
df['SM'].unique().tolist()
# Out:
# ['4★', '5★', '1★', '2★', '3★']

# %%
df['A/W'].unique().tolist()
# Out:
# ['Medium', 'High', 'Low']

# %%
df['D/W'].unique().tolist()
# Out:
# ['Low', 'Medium', 'High']

# %%
df['IR'].unique().tolist()
# Out:
# ['5 ★', '3 ★', '4 ★', '2 ★', '1 ★']

# %%
df['PAC'].unique().tolist()
# Out:
# [85,
#  89,
#  87,
#  76,
#  91,
#  78,
#  93,
#  86,
#  96,
#  88,
#  94,
#  65,
#  84,
#  74,
#  71,
#  77,
#  68,
#  75,
#  54,
#  79,
#  83,
#  80,
#  81,
#  82,
#  63,
#  67,
#  90,
#  66,
#  42,
#  73,
#  70,
#  64,
#  57,
#  58,
#  69,
#  72,
#  50,
#  59,
#  92,
#  60,
#  62,
#  55,
#  52,
#  56,
#  61,
#  53,
#  45,
#  37,
#  95,
#  43,
#  44,
#  46,
#  48,
#  49,
#  47,
#  34,
#  39,
#  40,
#  51,
#  41,
#  36,
#  32,
#  33,
#  30,
#  31,
#  38,
#  35,
#  28,
#  29,
#  25]

# %%
df['SHO'].unique().tolist()
# Out:
# [92,
#  93,
#  86,
#  85,
#  91,
#  88,
#  60,
#  73,
#  89,
#  87,
#  70,
#  90,
#  81,
#  66,
#  72,
#  82,
#  28,
#  74,
#  77,
#  62,
#  50,
#  83,
#  69,
#  80,
#  46,
#  76,
#  54,
#  49,
#  61,
#  58,
#  79,
#  68,
#  59,
#  41,
#  45,
#  64,
#  78,
#  55,
#  75,
#  65,
#  63,
#  48,
#  42,
#  56,
#  51,
#  30,
#  47,
#  84,
#  40,
#  57,
#  25,
#  71,
#  37,
#  43,
#  53,
#  67,
#  38,
#  52,
#  39,
#  35,
#  36,
#  44,
#  32,
#  34,
#  33,
#  31,
#  27,
#  22,
#  29,
#  26,
#  23,
#  18,
#  24,
#  20,
#  16,
#  21,
#  19,
#  17]

# %%
df['PAS'].unique().tolist()
# Out:
# [91,
#  81,
#  78,
#  93,
#  86,
#  85,
#  88,
#  71,
#  80,
#  76,
#  74,
#  77,
#  79,
#  84,
#  73,
#  55,
#  83,
#  87,
#  72,
#  75,
#  58,
#  89,
#  82,
#  68,
#  67,
#  64,
#  66,
#  59,
#  69,
#  90,
#  65,
#  53,
#  63,
#  62,
#  70,
#  56,
#  42,
#  54,
#  61,
#  57,
#  60,
#  48,
#  52,
#  47,
#  46,
#  44,
#  45,
#  50,
#  51,
#  49,
#  43,
#  36,
#  38,
#  40,
#  41,
#  35,
#  39,
#  34,
#  33,
#  37,
#  30,
#  32,
#  29,
#  31,
#  26,
#  28,
#  25,
#  27]

# %%
df['DRI'].unique().tolist()
# Out:
# [95,
#  89,
#  90,
#  88,
#  94,
#  85,
#  91,
#  71,
#  72,
#  86,
#  73,
#  81,
#  84,
#  92,
#  80,
#  68,
#  77,
#  87,
#  60,
#  83,
#  78,
#  64,
#  67,
#  79,
#  69,
#  66,
#  65,
#  70,
#  82,
#  75,
#  61,
#  74,
#  54,
#  76,
#  49,
#  63,
#  59,
#  62,
#  56,
#  55,
#  50,
#  57,
#  58,
#  52,
#  53,
#  51,
#  48,
#  47,
#  46,
#  39,
#  44,
#  43,
#  36,
#  40,
#  45,
#  41,
#  37,
#  34,
#  35,
#  42,
#  32,
#  38,
#  31,
#  33,
#  30,
#  29,
#  28,
#  25,
#  27]

# %%
df['DEF'].unique().tolist()
# Out:
# [38,
#  35,
#  52,
#  64,
#  36,
#  43,
#  45,
#  51,
#  39,
#  91,
#  44,
#  86,
#  48,
#  57,
#  40,
#  88,
#  33,
#  81,
#  63,
#  47,
#  53,
#  89,
#  71,
#  37,
#  80,
#  68,
#  85,
#  61,
#  90,
#  83,
#  49,
#  56,
#  58,
#  82,
#  87,
#  79,
#  66,
#  55,
#  78,
#  32,
#  50,
#  76,
#  77,
#  70,
#  75,
#  41,
#  29,
#  73,
#  65,
#  59,
#  84,
#  54,
#  72,
#  46,
#  42,
#  69,
#  34,
#  31,
#  30,
#  74,
#  24,
#  62,
#  25,
#  20,
#  26,
#  60,
#  27,
#  23,
#  28,
#  67,
#  22,
#  19,
#  18,
#  21,
#  17,
#  15,
#  16,
#  12]

# %%
df['PHY'].unique().tolist()
# Out:
# [65,
#  77,
#  90,
#  78,
#  59,
#  82,
#  75,
#  91,
#  76,
#  88,
#  86,
#  85,
#  73,
#  67,
#  79,
#  63,
#  83,
#  89,
#  66,
#  69,
#  72,
#  64,
#  71,
#  81,
#  87,
#  68,
#  84,
#  80,
#  55,
#  70,
#  44,
#  62,
#  51,
#  57,
#  60,
#  58,
#  56,
#  74,
#  52,
#  61,
#  53,
#  45,
#  50,
#  54,
#  47,
#  48,
#  49,
#  42,
#  37,
#  40,
#  39,
#  43,
#  38,
#  46,
#  41,
#  34,
#  35,
#  36,
#  31,
#  32,
#  33,
#  29,
#  28]

# %%
df['Hits'].unique().tolist()
# Out:
# ['771',
#  '562',
#  '150',
#  '207',
#  '595',
#  '248',
#  '246',
#  '120',
#  '1.6K',
#  '130',
#  '321',
#  '189',
#  '175',
#  '96',
#  '118',
#  '216',
#  '212',
#  '154',
#  '205',
#  '202',
#  '339',
#  '408',
#  '103',
#  '332',
#  '86',
#  '173',
#  '161',
#  '396',
#  '1.1K',
#  '433',
#  '242',
#  '206',
#  '177',
#  '1.5K',
#  '198',
#  '459',
#  '117',
#  '119',
#  '209',
#  '84',
#  '187',
#  '165',
#  '203',
#  '65',
#  '336',
#  '126',
#  '313',
#  '124',
#  '145',
#  '538',
#  '182',
#  '101',
#  '45',
#  '377',
#  '99',
#  '194',
#  '403',
#  '414',
#  '593',
#  '374',
#  '245',
#  '3.2K',
#  '266',
#  '299',
#  '309',
#  '215',
#  '265',
#  '211',
#  '112',
#  '337',
#  '70',
#  '159',
#  '688',
#  '116',
#  '63',
#  '144',
#  '123',
#  '71',
#  '224',
#  '113',
#  '168',
#  '61',
#  '89',
#  '137',
#  '278',
#  '75',
#  '148',
#  '176',
#  '197',
#  '264',
#  '214',
#  '247',
#  '402',
#  '440',
#  '1.7K',
#  '2.3K',
#  '171',
#  '320',
#  '657',
#  '87',
# ...
